# %% [markdown]
# # Initialization
# ## Imports

# %%
import pymupdf
from typing import Generator
path = "/home/timothee/Documents/data_challenges/PatentAssist/resources/Datasets - v1/Official Legal Publications/3-en-epc-guidelines-2024-hyperlinked.pdf"

# %% [markdown]
# ## Functions definition

# %%
def browse_summary(summary: list[list[3]]) -> Generator:
    levels = ["", "", "", ""]
    last_level = 0
    section_flag = 0
    for level, title, page_num in summary:
        if level < last_level:
            if section_flag == 1:
                section_flag = 0
                section_origin = list(filter(lambda x: x != "", levels))[-1]
                yield section_origin, begin_section-1, page_num

            for i in range(level, len(levels)):
                levels[i] = ""
        

        if title.lower().startswith("article") or title.lower().startswith("rule"):
            if level > last_level:
                begin_section = page_num
                section_flag = 1

        else:
            levels[level-1] = title

        last_level = level

# %%
def content_ref_split(page: pymupdf.Page, hoffset: int, woffset: int) -> tuple[dict]:
    height, width = page.rect.height, page.rect.width
    if page.number % 2 == 1:
        page.set_cropbox((0, hoffset, woffset, height))
        ref = page.get_text("dict", flags=11)["blocks"]
        page.set_cropbox((woffset, hoffset, width, height))
        content = page.get_text("dict", flags=11)["blocks"]
    else:
        page.set_cropbox((width-woffset, hoffset, width, height))
        ref = page.get_text("dict", flags=11)["blocks"]
        page.set_cropbox((0, hoffset, width-woffset, height))
        content = page.get_text("dict", flags=11)["blocks"]

    return ref, content

# %%
def extract_articles(blocks, ):
    pass

# %%
def manage_overlap(page_blocks, section_origin: str):
    section_type = " ".join(section_origin.split(" ")[:2])
    sections_landmarks = {}
    for i in range(len(page_blocks)):
        if len(page_blocks[i]["lines"]) > 0 and len(page_blocks[i]["lines"][0]["spans"]) > 0 and page_blocks[i]["lines"][0]["spans"][0]["font"] == "Arial-BoldMT" and page_blocks[i]["lines"][0]["spans"][0]["color"] != 0:
            text = " ".join(page_blocks[i]["lines"][0]["spans"][0]["text"].strip().split(" ")[:2])
            sections_landmarks[text] = i
    if section_type not in sections_landmarks:
        if len(sections_landmarks) > 0:
            i_end = next(iter(sections_landmarks.values()))
            return page_blocks[:i_end]
        else:
            return page_blocks
    else:
        i_deb = sections_landmarks[section_type]
        section_crossed = False
        i_end = len(page_blocks)
        for elem in sections_landmarks:
            if section_crossed:
                i_end = sections_landmarks[elem]
            if elem == section_type:
                section_crossed = True
        return page_blocks[i_deb:i_end]
#algo en pseudo code 
#récupérer le nom du chapitre associé
#chercher dans la page les blocks de séparation autres que "article" ou "rule"
#récupérer les indices correspondant aux blocks entre deux blocs de séparation
#si la balise du chapitre correspond, on prend tout ce qu'il y a après et avant éventuelle prochaine balise
#sinon on prend tout ce qu'il y a après et jusqu'à éventuelle prochaine balise

# %%
def extract_blocks(pdf: pymupdf.Document, section_origin: str, begin_section: int, end_section: int):
    blocks = []
    for pn in range(begin_section, end_section):
        page = pdf[pn]
        page_blocks = page.get_text("dict", flags=11)["blocks"]
        
        if pn == begin_section-1:
            blocks.extend(manage_overlap(page_blocks, section_origin))
        elif pn == end_section-1:
            blocks.extend(manage_overlap(page_blocks, section_origin))
        else:
            blocks.extend(page_blocks)

    return blocks

# %% [markdown]
# # Main loop

# %%
content = []
with pymupdf.open(path) as pdf:
    summary = pdf.get_toc()

    for section_of_interest in browse_summary(summary):
        section_origin, begin_section, end_section = section_of_interest
        blocks_of_interest = extract_blocks(pdf, section_origin, begin_section, end_section)
        section_articles = extract_articles(blocks_of_interest)
        for article in section_articles:
            article["origin"] = " -> ".join(section_origin)
        content.extend(section_articles)

    for level, title, page in summary:
        indent = "   "*(level-1)
        print(f"{indent}{title} -> {page}")
# Out:
# <class 'pymupdf.Document'>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[57], line 5
#       2 print(type(pdf))
#       3 summary = pdf.get_toc()
# ----> 5 for section_of_interest in browse_summary(summary):
#       6     pass
#       7     #do_something(section of interest)
#
# NameError: name 'browse_summary' is not defined

# %%
page_num = 44
with pymupdf.open(path) as pdf:
    page = pdf[page_num]
    for block in page.get_text("dict", flags=11)["blocks"]:
        for line in block["lines"]:
            for span in line["spans"]:
                print(f"{span['font']}\n{span['text']}\n{span['size']}\n----------")
            print("----- EOL -----")
        print("----- EOB -----")
# Out:
# Arial
# March 2024
# 9.0
# ----------
# ----- EOL -----
# Arial
# Guidelines for Examination in the EPO
# 9.0
# ----------
# ----- EOL -----
# Arial
# Part A – Chapter II-3
# 9.0
# ----------
# ----- EOL -----
# ----- EOB -----
# Arial,Bold
# 1.3 Filing of applications by other means
# 11.039999961853027
# ----------
# ----- EOL -----
# Arial
# The filing of European patent applications by other means such as
# 11.039999961853027
# ----------
# Arial,Bold
# email
# 11.039999961853027
# ----------
# Arial
#  is
# 11.039999961853027
# ----------
# Arial,Bold
#
# 11.039999961853027
# ----------
# ----- EOL -----
# Arial
# at present not allowed (see also the notice from the EPO dated
# 11.039999961853027
# ----------
# ----- EOL -----
# Arial
# 12 September 2000,
# 11.039999961853027
# ----------
# Arial
# OJ EPO 2000, 458
# 11.039999961853027
# ----------
# Arial
# ).
# 11.039999961853027
# ----------
# ----- EOL -----
# ----- EOB -----
# Arial,Bold
# 1.4 Subsequent filing of documents
# 11.039999961853027
# ----------
# ----- EOL -----
# Arial
# For the subsequent filing of documents, see
# 11.039999961853027
# ----------
# Arial
# A-VIII, 2.5
# 11.039999961853027
# ----------
# Arial
# .
# 11.039999961853027
# ----------
# ----- EOL -----
# ----- EOB -----
# Arial,Bold
# 1.5 Debit orders for deposit accounts held with the EPO
# 11.039999961853027
# ----------
# ----- EOL -----
# Arial
# For European patent applications, debit orders for the fees due must be
# 11.039999961853027
# ----------
# ----- EOL -----
# Arial
# filed in an accepted electronic format (see
# 11.039999961853027
# ----------
# Arial
# A-X, 4.2.3
# 11.039999961853027
# ----------
# Arial
# ), irrespective of how
# 11.039999961853027
# ----------
# ----- EOL -----
# Arial
# the application itself is filed. If an application is filed with a competent
# 11.039999961853027
# ----------
# ----- EOL -----
# Arial
# national authority (
# 11.039999961853027
# ----------
# Arial
# Art. 75(1)(b)
# 11.039999961853027
# ----------
# Arial
# ) on paper, a paper debit order on
# 11.039999961853027
# ----------
# ----- EOL -----
# Arial
# mandatory Form 1020 for the fees intended to be paid is accepted by way
# 11.039999961853027
# ----------
# ----- EOL -----
# Arial
# of exception if it is included with that application on filing (see the
# 11.039999961853027
# ----------
# ----- EOL -----
# Arial
# Arrangements for deposit accounts (ADA),
# 11.039999961853027
# ----------
# Arial
# Supplementary publication 3,
# 11.039999961853027
# ----------
# Arial
#
# 11.039999961853027
# ----------
# ----- EOL -----
# Arial
# OJ EPO 2022
# 11.039999961853027
# ----------
# Arial
# ,
# 11.039999961853027
# ----------
# Arial
# Supplementary publication 3, OJ EPO 2023, 10
# 11.039999961853027
# ----------
# Arial
# , and the
# 11.039999961853027
# ----------
# ----- EOL -----
# Arial
# decision
# 11.039999961853027
# ----------
# ----- EOL -----
# Arial
# of
# 11.039999961853027
# ----------
# ----- EOL -----
# Arial
# the
# 11.039999961853027
# ----------
# ----- EOL -----
# Arial
# President
# 11.039999961853027
# ----------
# ----- EOL -----
# Arial
# of
# 11.039999961853027
# ----------
# ----- EOL -----
# Arial
# the
# 11.039999961853027
# ----------
# ----- EOL -----
# Arial
# EPO
# 11.039999961853027
# ----------
# ----- EOL -----
# Arial
# dated
# 11.039999961853027
# ----------
# ----- EOL -----
# Arial
# 13 June
# 11.039999961853027
# ----------
# ----- EOL -----
# Arial
# 2023,
# 11.039999961853027
# ----------
# ----- EOL -----
# Arial
# OJ EPO 2023, A58)
# 11.039999961853027
# ----------
# Arial
# . Paper Form 1020 is not accepted if filed direct with
# 11.039999961853027
# ----------
# ----- EOL -----
# Arial
# the EPO.
# 11.039999961853027
# ----------
# ----- EOL -----
# ----- EOB -----
# Arial,Bold
# 1.6 Forwarding of applications
# 11.039999961853027
# ----------
# ----- EOL -----
# Arial
# The central industrial property office of a contracting state is obliged to
# 11.039999961853027
# ----------
# ----- EOL -----
# Arial
# forward applications filed (see
# 11.039999961853027
# ----------
# Arial
# A-II, 3.2)
# 11.039999961853027
# ----------
# Arial
#  with it or with other competent
# 11.039999961853027
# ----------
# ----- EOL -----
# Arial
# authorities in that state to the EPO in the shortest time compatible with its
# 11.039999961853027
# ----------
# ----- EOL -----
# Arial
# national law on the secrecy of inventions (for debit order enclosures,
# 11.039999961853027
# ----------
# ----- EOL -----
# Arial
# see
# 11.039999961853027
# ----------
# Arial
# A-II, 1.5)
# 11.039999961853027
# ----------
# Arial
# .
# 11.039999961853027
# ----------
# ----- EOL -----
# ----- EOB -----
# Arial
# A time limit of six weeks after filing is specified for the onward transmission
# 11.039999961853027
# ----------
# ----- EOL -----
# Arial
# to the EPO of applications not classified as secret. This is extended to four
# 11.039999961853027
# ----------
# ----- EOL -----
# Arial
# months or, where priority has been claimed, to 14 months after the date of
# 11.039999961853027
# ----------
# ----- EOL -----
# Arial
# priority, for applications requiring further examination as to their
# 11.039999961853027
# ----------
# ----- EOL -----
# Arial
# classification as secret. An application received outside the specified time
# 11.039999961853027
# ----------
# ----- EOL -----
# Arial
# limits, either six weeks or four months, must be processed, provided it is
# 11.039999961853027
# ----------
# ----- EOL -----
# Arial
# received in Munich, The Hague or Berlin before the end of the 14th month
# 11.039999961853027
# ----------
# ----- EOL -----
# Arial
# after filing or, where appropriate, after the date of priority. Applications
# 11.039999961853027
# ----------
# ----- EOL -----
# Arial
# received after 14 months are deemed withdrawn. Re-establishment of
# 11.039999961853027
# ----------
# ----- EOL -----
# Arial
# rights and further processing in respect of the period under
# 11.039999961853027
# ----------
# Arial
# Rule 37(2)
# 11.039999961853027
# ----------
# Arial
#  are
# 11.039999961853027
# ----------
# ----- EOL -----
# Arial
# not possible, since the loss of rights does not result from the applicant's
# 11.039999961853027
# ----------
# ----- EOL -----
# Arial
# failure to observe a time limit (see
# 11.039999961853027
# ----------
# Arial
# J 3/80)
# 11.039999961853027
# ----------
# Arial
# . However, the applicant may file
# 11.039999961853027
# ----------
# ----- EOL -----
# Arial
# a request for conversion under
# 11.039999961853027
# ----------
# Arial
# Art. 135(1)(a)
# 11.039999961853027
# ----------
# Arial
#  (see
# 11.039999961853027
# ----------
# Arial
# A-IV, 6
# 11.039999961853027
# ----------
# Arial
# ).
# 11.039999961853027
# ----------
# ----- EOL -----
# ----- EOB -----
# Arial
# If the time limit referred to in
# 11.039999961853027
# ----------
# Arial
# Rule 37(2)
# 11.039999961853027
# ----------
# Arial
#  expires on a day on which the
# 11.039999961853027
# ----------
# ----- EOL -----
# Arial
# delivery or transmission of mail is interrupted or subsequently dislocated
# 11.039999961853027
# ----------
# ----- EOL -----
# Arial
# within the meaning of
# 11.039999961853027
# ----------
# Arial
# Rule 134(2)
# 11.039999961853027
# ----------
# Arial
# , it will extend to the first day following the
# 11.039999961853027
# ----------
# ----- EOL -----
# Arial
# end of the period of interruption or dislocation.
# 11.039999961853027
# ----------
# ----- EOL -----
# ----- EOB -----
# Arial,Italic
# Point 7.1.2 ADA
# 9.960000038146973
# ----------
# ----- EOL -----
# Arial,Italic
# Point 12.1 ADA
# 9.960000038146973
# ----------
# ----- EOL -----
# ----- EOB -----
# Arial,Italic
# Art. 77(1)
# 9.960000038146973
# ----------
# ----- EOL -----
# Arial,Italic
# Rule 37(1)
# 9.960000038146973
# ----------
# Arial,Italic
#
# 9.960000038146973
# ----------
# ----- EOL -----
# ----- EOB -----
# Arial,Italic
# Art. 77(3)
# 9.960000038146973
# ----------
# ----- EOL -----
# Arial,Italic
# Rule 37(2)
# 9.960000038146973
# ----------
# Arial,Italic
#
# 9.960000038146973
# ----------
# ----- EOL -----
# Arial,Italic
# Art. 135(1)(a)
# 9.960000038146973
# ----------
# Arial,Italic
#
# 9.960000038146973
# ----------
# ----- EOL -----
# ----- EOB -----
# Arial,Italic
# Rule 134(2)
# 9.960000038146973
# ----------
# Arial,Italic
#
# 9.960000038146973
# ----------
# ----- EOL -----
# ----- EOB -----

# %%
page_num = 47
hoffset = 70
woffset = 160
with pymupdf.open(path) as pdf:
    page = pdf[page_num]
    
    ref, content = content_ref_split(page, hoffset, woffset)
    print("REF")
    for block in ref:
        print("BLOCK", block["bbox"])
        for line in block["lines"]:
            for span in line["spans"]:
                print(span["text"], span["xref"])
        print("----- EOB -----")
    print("-----------")
    print("CONTENT")
    for block in content:
        print("BLOCK ", block["bbox"])
        for line in block["lines"]:
            for span in line["spans"]:
                print(span["text"], "->")
        print("----- EOB -----")
# Out:
# REF
# BLOCK (56.63999938964844, 11.739912033081055, 111.6288833618164, 51.81695556640625)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[72], line 13
#      11     for line in block["lines"]:
#      12         for span in line["spans"]:
# ---> 13             print(span["text"], span["xref"])
#      14     print("----- EOB -----")
#      15 print("-----------")
#
# KeyError: 'xref'

# %%
with pymupdf.open(path) as pdf:
    last_page_num = -1
    for page in pdf:
        pdf[12].get_text(xref=3349)
        print(page.get_links())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[73], line 4
#       2 last_page_num = -1
#       3 for page in pdf:
# ----> 4     pdf[12].get_text(xref=3349)
#       5     print(page.get_links())
#
# TypeError: get_text() got an unexpected keyword argument 'xref'
