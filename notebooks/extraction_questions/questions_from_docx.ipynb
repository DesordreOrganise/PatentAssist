# %%
try:
    from xml.etree.cElementTree import XML
except ImportError:
    from xml.etree.ElementTree import XML
import zipfile


"""
Module that extract text from MS XML Word document (.docx).
(Inspired by python-docx <https://github.com/mikemaccana/python-docx>)
"""

WORD_NAMESPACE = '{http://schemas.openxmlformats.org/wordprocessingml/2006/main}'
PARA = WORD_NAMESPACE + 'p'
TEXT = WORD_NAMESPACE + 't'


def get_docx_text(path):
    """
    Take the path of a docx file as argument, return the text in unicode.
    """
    document = zipfile.ZipFile(path)
    xml_content = document.read('word/document.xml')
    document.close()
    tree = XML(xml_content)

    paragraphs = []
    for paragraph in tree.iter(PARA):
        texts = [node.text
                 for node in paragraph.iter(TEXT)
                 if node.text]
        if texts:
            paragraphs.append(''.join(texts))

    return '\n\n'.join(paragraphs)

# %%
txt = get_docx_text("../../resources/Categories.docx")

# %%
len(txt)
# Out:
# 23061

# %%
import pymupdf
import re

theme_pattern = re.compile(r"^\d\.\s")
subtopic_pattern = re.compile(r"^\d\.\d+\s")

path = "../../resources/Categories.pdf"


themes = []
with pymupdf.open(path) as pdf:
    pages = pdf[0:13]
    for page in pages:
        for block in page.get_text("dict", flags=11)["blocks"]:
            for line in block["lines"]:
                for span in line["spans"]:
                    print(span["text"])

            print("---------- EOB -----------")

    for page in pages:
        theme = {}
        begin_sentences = 0
        sentences = []
        for block in page.get_text("dict", flags=11)["blocks"]:
            for line in block["lines"]:
                if begin_sentences == 1:
                    sentences.append(" ".join([span["text"].strip() for span in line["spans"]]))
                first_elem = line["spans"][0]["text"].strip()
                if theme_pattern.match(first_elem):
                    if begin_sentences == 1:
                        theme["sentences"] = sentences[:-1]
                        sentences = []
                    begin_sentences = 0
                    theme["topic"] = " ".join([span["text"].strip() for span in line["spans"]])
                elif subtopic_pattern.match(first_elem):
                    if begin_sentences == 1:
                        theme["sentences"] = sentences[:-1]
                        sentences = []
                    begin_sentences = 0
                    theme["subtopic"] = " ".join([span["text"].strip() for span in line["spans"]])
                elif first_elem.startswith("Scope"):
                    theme["scope"] = " ".join([span["text"].strip() for span in line["spans"]])
                elif first_elem.startswith("Sample"):
                    begin_sentences = 1
            themes.append(theme)
                
                


"""             stripped = line.strip("• ").strip("◦ ").strip()
            if theme_pattern.match(stripped):
                print(f"Theme: {stripped}")
            elif subtopic_pattern.match(stripped):
                print(f"Subtopic: {stripped}")
            elif stripped.startswith("Scope:"):
                print(f"Scope: {stripped}")
            elif stripped.startswith("Sample"):
                pass
            else:
                print(f"Question: {stripped}") """
# Out:
# 1. Filing requirements and formalities
# ---------- EOB -----------
# 1.1 Minimum requirements for a filing date
# ---------- EOB -----------
# 
# Scope
# : assessing the mandatory elements (e.g., description, claims) and
# their submission modes.
# ---------- EOB -----------
# 
#  Sample sentences:
# ---------- EOB -----------
# o
# What documents are required on the filing date for the epo to
# accord a filing date?
# ---------- EOB -----------
# o
# How is the filing date affected if claims are missing initially?
# ---------- EOB -----------
# o
# If no reference to any drawing is included, can missing drawings be
# submitted later without a change in the filing date?
# ---------- EOB -----------
# 1.2 Filing methods and locations
# ---------- EOB -----------
# 
# Scope
# : addressing allowed filing modes (fax, online, physical) and relevant
# epo sites.
# ---------- EOB -----------
# 
#  Sample sentences:
# ---------- EOB -----------
# o
# Which epo offices can receive an ep application filed via fax?
# ---------- EOB -----------
# o
# How do the rules differ for filing with the epo vs. National patent
# offices?
# ---------- EOB -----------
# 1.3 Formality examination
# ---------- EOB -----------
# 
# Scope
# : checking if formal requirements (payment of fees, form usage,
# etc.) Are met.
# ---------- EOB -----------
# 
#  Sample sentences:
# ---------- EOB -----------
# o
# What happens if the request for grant (form 1001) is not correctly
# completed?
# ---------- EOB -----------
# o
# What is the procedure if the formalities officer notes a missing
# inventor designation?
# ---------- EOB -----------
# 2. Priority claims and right of priority
# ---------- EOB -----------
# 2.1 Substantive requirements for priority
# ---------- EOB -----------
# 
# Scope
# : validity criteria, same invention requirement, earliest date, and
# partial priorities.
# ---------- EOB -----------
# 
#  Sample sentences:
# ---------- EOB -----------
# o
# What conditions must be fulfilled for a valid priority claim from an
# earlier application?
# ---------- EOB -----------
# o
# Does the priority application need to disclose every feature claimed
# in the subsequent filing?
# ---------- EOB -----------
# 2.2 Time limits and restoration
# ---------- EOB -----------
# 
# Scope
# : one-year priority period, procedures for requesting restoration,
# conditions for success.
# ---------- EOB -----------
# 
#  Sample sentences:
# ---------- EOB -----------
# o
# How is the 12-month priority period calculated when it ends on a
# weekend?
# ---------- EOB -----------
# o
# What evidence must be provided to restore priority under rule
# 26bis.3 pct?
# ---------- EOB -----------
# 2.3 Multiple priorities and partial priority
# ---------- EOB -----------
# 
# Scope
# : handling claims that rely on more than one earlier application.
# ---------- EOB -----------
# 
#  Sample sentences:
# ---------- EOB -----------
# o
# Can a single claim contain subject-matter from two different priority
# dates?
# ---------- EOB -----------
# o
# How to split claims into portions entitled to partial priority?
# ---------- EOB -----------
# 3. Divisional applications
# ---------- EOB -----------
# 3.1 Filing requirements
# ---------- EOB -----------
# 
# Scope
# : when a parent must still be pending, language options, and timing.
# ---------- EOB -----------
# 
#  Sample sentences:
# ---------- EOB -----------
# o
# By what date must a divisional be filed if the parent is due to grant?
# ---------- EOB -----------
# o
# Can a divisional be filed in a different language than its parent?
# ---------- EOB -----------
# 3.2 Subject-matter and scope
# ---------- EOB -----------
# 
# Scope
# : compliance with article 76 epc, no added subject-matter, and
# ensuring unity.
# ---------- EOB -----------
# 
#  Sample sentences:
# ---------- EOB -----------
# o
# How is added subject-matter assessed in a divisional relative to the
# parent’s original disclosure?
# ---------- EOB -----------
# o
# Can a divisional cover an invention that was excluded from the
# parent’s search due to lack of unity?
# ---------- EOB -----------
# 3.3 Fees for divisionals
# ---------- EOB -----------
# 
# Scope
# : payment of filing fees, renewal fees, examination fees, and other
# relevant costs.
# ---------- EOB -----------
# 
#  Sample sentences:
# ---------- EOB -----------
# o
# When are renewal fees due for a divisional application compared to
# its parent?
# ---------- EOB -----------
# o
# Is any reduction possible for the filing or examination fee of a
# divisional?
# ---------- EOB -----------
# 4. Fees, payment methods, and time limits
# ---------- EOB -----------
# 4.1 Types and calculation of fees
# ---------- EOB -----------
# 
# Scope
# : understanding different fee types (filing, search, examination,
# renewal, claims).
# ---------- EOB -----------
# 
#  Sample sentences:
# ---------- EOB -----------
# o
# How are excess claims fees calculated if claims are amended during
# examination?
# ---------- EOB -----------
# o
# When must the search fee be paid if the epo acts as isa under the
# pct?
# ---------- EOB -----------
# 4.2 Payment mechanisms
# ---------- EOB -----------
# 
# Scope
# : automatic debit orders, bank transfers, credit cards, and fee
# payment via third parties.
# ---------- EOB -----------
# 
#  Sample sentences:
# ---------- EOB -----------
# o
# How does an automatic debit order work and what happens if the
# deposit account lacks funds?
# ---------- EOB -----------
# o
# Can multiple applicants share a single deposit account for fee
# payment?
# ---------- EOB -----------
# 4.3 Fee deadlines and late payment consequences
# ---------- EOB -----------
# 
# Scope
# : additional fees, surcharges, and further processing if deadlines are
# missed.
# ---------- EOB -----------
# 
#  Sample sentences:
# ---------- EOB -----------
# o
# What surcharge applies if renewal fees are not paid by the due
# date?
# ---------- EOB -----------
# o
# How can an applicant avoid loss of rights if a fee payment is
# overlooked?
# ---------- EOB -----------
# 5. Languages and translations
# ---------- EOB -----------
# 5.1 Language of filing and procedural language
# ---------- EOB -----------
# 
# Scope
# : filing in non-epo official languages, subsequent translation
# deadlines, language-based fee reductions.
# ---------- EOB -----------
# 
#  Sample sentences:
# ---------- EOB -----------
# o
# How long after filing must a translation be submitted if the
# application was filed in italian?
# ---------- EOB -----------
# o
# Which official language of the epo becomes the language of
# proceedings if multiple languages are used?
# ---------- EOB -----------
# 5.2 Translation requirements on grant or other stages
# ---------- EOB -----------
# 
# Scope
# : claim translations under rule 71(3) epc, translation for validation in
# national phases.
# ---------- EOB -----------
# 
#  Sample sentences:
# ---------- EOB -----------
# o
# What is required if the text intended for grant is not in the
# applicant’s preferred official language?
# ---------- EOB -----------
# o
# Does the applicant need to file translations in all contracting states
# after grant?
# ---------- EOB -----------
# 5.3 Effects of language on costs and procedural rights
# ---------- EOB -----------
# 
# Scope
# : fee reductions for certain languages, language-based rights of
# small entities or universities.
# ---------- EOB -----------
# 
#  Sample sentences:
# ---------- EOB -----------
# o
# What reduction in examination fees applies for a university filing in
# an official language of an epc contracting state?
# ---------- EOB -----------
# o
# Can an applicant who filed in spanish benefit from a fee reduction?
# ---------- EOB -----------
# 6. Procedural remedies and legal effect
# ---------- EOB -----------
# 6.1 Further processing (rule 135 epc)
# ---------- EOB -----------
# 
# Scope
# : available for missed deadlines in examination or other
# proceedings, scope of remedy, exceptions.
# ---------- EOB -----------
# 
#  Sample sentences:
# ---------- EOB -----------
# o
# For which official time limits is further processing not available?
# ---------- EOB -----------
# o
# How must an applicant request further processing after failing to
# respond to an examination report?
# ---------- EOB -----------
# 6.2 Re-establishment of rights (article 122 epc)
# ---------- EOB -----------
# 
# Scope
# : conditions (all due care), time limit for requesting, and required
# evidence.
# ---------- EOB -----------
# 
#  Sample sentences:
# ---------- EOB -----------
# o
# What steps demonstrate “all due care” to justify re-establishment?
# ---------- EOB -----------
# o
# When does the two-month time limit for re-establishment start
# running if an applicant misses a final deadline?
# ---------- EOB -----------
# 6.3 Loss of rights and remedies
# ---------- EOB -----------
# 
# Scope
# : notices of loss of rights, deemed withdrawals, subsequent
# procedural options.
# ---------- EOB -----------
# 
#  Sample sentences:
# ---------- EOB -----------
# o
# When is a communication under rule 112(1) epc issued, and how to
# react?
# ---------- EOB -----------
# o
# Is an appeal possible against a deemed withdrawal?
# ---------- EOB -----------
# 7. Pct procedure and entry into the european phase
# ---------- EOB -----------
# 7.1 International filing and search
# ---------- EOB -----------
# 
# Scope
# : filing at receiving offices, international search by epo or other isas,
# invited corrections.
# ---------- EOB -----------
# 
#  Sample sentences:
# ---------- EOB -----------
# o
# Which receiving office can a us applicant choose when filing a pct
# application?
# ---------- EOB -----------
# o
# What happens if the applicant fails to pay the international filing fee
# within the deadline?
# ---------- EOB -----------
# 7.2 Preliminary examination and amendments
# ---------- EOB -----------
# 
# Scope
# : filing a demand, timing for article 34 amendments, unity objections
# at iper stage.
# ---------- EOB -----------
# 
#  Sample sentences:
# ---------- EOB -----------
# o
# When must the demand for international preliminary examination
# be filed at the epo as ipea?
# ---------- EOB -----------
# o
# How are amendments under article 34 pct handled differently from
# article 19 pct amendments?
# ---------- EOB -----------
# 7.3 European phase entry and requirements
# ---------- EOB -----------
# 
# Scope
# : minimum actions to enter ep phase (translations, fees, etc.),
# optional actions (requesting examination).
# ---------- EOB -----------
# 
#  Sample sentences:
# ---------- EOB -----------
# o
# What are the minimum requirements to validly enter the european
# phase under articles 22/39 pct?
# ---------- EOB -----------
# o
# Is an additional search fee always required in the ep phase if the
# epo was the isa?
# ---------- EOB -----------
# 8. Examination, amendments, and grant
# ---------- EOB -----------
# 8.1 Examination procedure and communications
# ---------- EOB -----------
# 
# Scope
# : responding to article 94(3) communications, telephone
# consultations with examiners, time limit extensions.
# ---------- EOB -----------
# 
#  Sample sentences:
# ---------- EOB -----------
# o
# What are the applicant’s options upon receiving an objection
# regarding lack of clarity under article 84?
# ---------- EOB -----------
# o
# Is an in-person hearing possible before the examining division issues
# a final decision?
# ---------- EOB -----------
# 8.2 Claim amendments and article 123 epc
# ---------- EOB -----------
# 
# Scope
# : no added subject-matter, no broadening after grant, clarity
# considerations.
# ---------- EOB -----------
# 
#  Sample sentences:
# ---------- EOB -----------
# o
# How is an amendment evaluated for compliance with article 123(2)?
# ---------- EOB -----------
# o
# When is it permissible to delete features from the original
# independent claim?
# ---------- EOB -----------
# 8.3 Grant stage (rule 71(3) epc) and post-grant publication
# ---------- EOB -----------
# 
# Scope
# : paying the fee for grant and publishing, submitting claim
# translations, final text for publication.
# ---------- EOB -----------
# 
#  Sample sentences:
# ---------- EOB -----------
# o
# What steps must be completed before the decision to grant is
# issued?
# ---------- EOB -----------
# o
# What happens if errors are found in the druckexemplar after paying
# the grant fee?
# ---------- EOB -----------
# 9. Opposition and appeals
# ---------- EOB -----------
# 9.1 Grounds for opposition (article 100 epc)
# ---------- EOB -----------
# 
# Scope
# : novelty, inventive step, subject-matter not patentable,
# insufficiency of disclosure, extension beyond original filing.
# ---------- EOB -----------
# 
#  Sample sentences:
# ---------- EOB -----------
# o
# Can an opponent rely on lack of clarity under article 84 epc as a
# ground for opposition?
# ---------- EOB -----------
# o
# Is lack of unity a valid ground for opposition?
# ---------- EOB -----------
# 9.2 Opposition procedure and admissibility
# ---------- EOB -----------
# 
# Scope
# : formal requirements (time limits, opponent identity), partial
# opposition, withdrawal of opposition.
# ---------- EOB -----------
# 
# Sample sentences:
# ---------- EOB -----------
# o
# Is it possible to oppose only one independent claim of a granted
# patent?
# ---------- EOB -----------
# o
# How does the epo handle late-filed documents in opposition?
# ---------- EOB -----------
# 9.3 Appeal proceedings
# ---------- EOB -----------
# 
# Scope
# : grounds of appeal, fresh evidence, remittal, boards’ powers, and
# procedures.
# ---------- EOB -----------
# 
#  Sample sentences:
# ---------- EOB -----------
# o
# Can a new ground for opposition be introduced during appeal
# without the patentee’s consent?
# ---------- EOB -----------
# o
# What is the composition of a board of appeal deciding a patent
# case?
# ---------- EOB -----------
# 10. Substantive patent law: novelty and inventive step
# ---------- EOB -----------
# 10.1 Novelty analysis
# ---------- EOB -----------
# 
# Scope
# : defining prior art, comparing features, selection inventions,
# disclaimers.
# ---------- EOB -----------
# 
#  Sample sentences:
# ---------- EOB -----------
# o
# How is novelty assessed against a document that discloses a range
# overlapping the claimed range?
# ---------- EOB -----------
# o
# Does prior use by the applicant themselves destroy novelty?
# ---------- EOB -----------
# 10.2 Inventive step analysis
# ---------- EOB -----------
# 
# Scope
# : closest prior art selection, objective technical problem, and
# problem-solution approach.
# ---------- EOB -----------
# 
#  Sample sentences:
# ---------- EOB -----------
# o
# Can a known alternative material render the claim obvious if it
# provides no improved result?
# ---------- EOB -----------
# o
# How does the examiner establish a lack of inventive step if the
# solution is an obvious combination of known teachings?
# ---------- EOB -----------
# 10.3 Special forms of claims (e.g., medical use)
# ---------- EOB -----------
# 
# Scope
# : swiss-type, article 54(5) epc second medical use claims, allowable
# claim wording.
# ---------- EOB -----------
# 
#  Sample sentences:
# ---------- EOB -----------
# o
# What is the difference between swiss-type claims and epc 2000
# medical use claims?
# ---------- EOB -----------
# o
# How is novelty established for a second or further medical use?
# ---------- EOB -----------
# 11. Entitlement and transfers
# ---------- EOB -----------
# 11.1 Entitlement disputes (article 61 EPC)
# ---------- EOB -----------
# 
# Scope
# : disputes over who owns the right to a european patent application
# or patent.
# ---------- EOB -----------
# 
#  Sample sentences:
# ---------- EOB -----------
# o
# How can proceedings be stayed if entitlement proceedings are
# initiated before a national court?
# ---------- EOB -----------
# o
# What is the effect on the ongoing examination of a pending
# entitlement dispute?
# ---------- EOB -----------
# 11.2 Transfers and assignments
# ---------- EOB -----------
# 
# Scope
# : formalities for registering changes in ownership, partial transfers,
# and licensing.
# ---------- EOB -----------
# 
#  Sample sentences:
# ---------- EOB -----------
# o
# Which documents are needed to record a transfer of rights in the
# european patent register?
# ---------- EOB -----------
# o
# Does a partial assignment allow different co-owners in different
# designated states?
# ---------- EOB -----------
# 11.3 Procedural consequences
# ---------- EOB -----------
# 
# Scope
# : impact on deadlines, actions that can/cannot be taken by a
# transferee before registration.
# ---------- EOB -----------
# 
#  Sample sentences:
# ---------- EOB -----------
# o
# At what point can the transferee begin prosecuting the application
# in their own name?
# ---------- EOB -----------
# o
# Is there a fee for recording a transfer at the epo?
# ---------- EOB -----------
# 12. Biotech and sequence listings
# ---------- EOB -----------
# 12.1 Sequence listing filing and format
# ---------- EOB -----------
# 
# Scope
# : mandatory wipo standard, electronic submission, late furnishing
# fees.
# ---------- EOB -----------
# 
#  Sample sentences:
# ---------- EOB -----------
# o
# What are the consequences if a sequence listing is not filed upon
# request?
# ---------- EOB -----------
# o
# In what format must the sequence listing be provided under wipo
# standard st.25 or st.26?
# ---------- EOB -----------
# 12.2 Added subject-matter in biotech claims
# ---------- EOB -----------
# 
# Scope
# : ensuring that no new sequences or mutations are introduced
# beyond the original disclosure.
# ---------- EOB -----------
# 
#  Sample sentences:
# ---------- EOB -----------
# o
# How is compliance with article 123(2) epc checked for nucleotide
# and amino acid sequences?
# ---------- EOB -----------
# 12.3 Specific patentability exceptions in biotech
# ---------- EOB -----------
# 
# Scope
# : exclusions (plant/animal varieties, essentially biological processes),
# rule 28 epc.
# ---------- EOB -----------
# 
#  Sample sentences:
# ---------- EOB -----------
# o
# What biotech inventions are explicitly excluded from patentability
# under the epc?
# ---------- EOB -----------
# o
# Does the epc allow gene editing claims for plants?
# ---------- EOB -----------
# 13. Unity of invention
# ---------- EOB -----------
# 13.1 Unity in european applications
# ---------- EOB -----------
# 
# Scope
# : criteria for single general inventive concept, partial search where
# unity is lacking.
# ---------- EOB -----------
# 
#  Sample sentences:
# ---------- EOB -----------
# o
# How does the epo handle multiple independent claims that appear
# unrelated?
# ---------- EOB -----------
# o
# Can the epo invite payment of additional search fees for non-unified
# claims during ep examination?
# ---------- EOB -----------
# 13.2 Unity in pct applications
# ---------- EOB -----------
# 
# Scope
# : international phase unity criteria, additional fees for multiple
# inventions, protest procedure.
# ---------- EOB -----------
# 
#  Sample sentences:
# ---------- EOB -----------
# o
# What steps can an applicant take if the isa invites payment of
# additional search fees?
# ---------- EOB -----------
# o
# Is it possible to pursue unsearched inventions in a later european
# divisional?
# ---------- EOB -----------
# 13.3 Strategies for overcoming lack of unity
# ---------- EOB -----------
# 
# Scope
# : amendments, selecting one invention to proceed with, potential
# divisional filings.
# ---------- EOB -----------
# 
#  Sample sentences:
# ---------- EOB -----------
# o
# Which claims should be retained if the applicant pays no additional
# search fees?
# ---------- EOB -----------
# o
# How does an applicant choose the invention providing the strongest
# prospect of allowance?
# ---------- EOB -----------
# '             stripped = line.strip("• ").strip("◦ ").strip()\n            if theme_pattern.match(stripped):\n                print(f"Theme: {stripped}")\n            elif subtopic_pattern.match(stripped):\n                print(f"Subtopic: {stripped}")\n            elif stripped.startswith("Scope:"):\n                print(f"Scope: {stripped}")\n            elif stripped.startswith("Sample"):\n                pass\n            else:\n                print(f"Question: {stripped}") '

# %%
import pandas as pd
import json
with open("../../resources/questions/epo_topics_structure.json", 'r') as js:
    themes = json.load(js)
df = pd.DataFrame.from_dict(themes)

# %%
themes
# Out:
# [{'topic': '1. Filing requirements and formalities',
#   'subtopic': '1.1 Minimum requirements for a filing date',
#   'scope': 'assessing the mandatory elements (e.g., description, claims) and their submission modes.',
#   'questions': ['What documents are required on the filing date for the epo to accord a filing date?',
#    'How is the filing date affected if claims are missing initially?',
#    'If no reference to any drawing is included, can missing drawings be submitted later without a change in the filing date?']},
#  {'topic': '1. Filing requirements and formalities',
#   'subtopic': '1.2 Filing methods and locations',
#   'scope': 'addressing allowed filing modes (fax, online, physical) and relevant epo sites.',
#   'questions': ['Which epo offices can receive an ep application filed via fax?',
#    'How do the rules differ for filing with the epo vs. National patent offices?']},
#  {'topic': '1. Filing requirements and formalities',
#   'subtopic': '1.3 Formality examination',
#   'scope': 'checking if formal requirements (payment of fees, form usage, etc.) Are met.',
#   'questions': ['What happens if the request for grant (form 1001) is not correctly completed?',
#    'What is the procedure if the formalities officer notes a missing inventor designation?']},
#  {'topic': '2. Priority claims and right of priority',
#   'subtopic': '2.1 Substantive requirements for priority',
#   'scope': 'validity criteria, same invention requirement, earliest date, and partial priorities.',
#   'questions': ['What conditions must be fulfilled for a valid priority claim from an earlier application?',
#    'Does the priority application need to disclose every feature claimed in the subsequent filing?']},
#  {'topic': '2. Priority claims and right of priority',
#   'subtopic': '2.2 Time limits and restoration',
#   'scope': 'one-year priority period, procedures for requesting restoration, conditions for success.',
#   'questions': ['How is the 12-month priority period calculated when it ends on a weekend?',
#    'What evidence must be provided to restore priority under rule 26bis.3 pct?']},
#  {'topic': '2. Priority claims and right of priority',
#   'subtopic': '2.3 Multiple priorities and partial priority',
#   'scope': 'handling claims that rely on more than one earlier application.',
#   'questions': ['Can a single claim contain subject-matter from two different priority dates?',
#    'How to split claims into portions entitled to partial priority?']},
#  {'topic': '3. Divisional applications',
#   'subtopic': '3.1 Filing requirements',
#   'scope': 'when a parent must still be pending, language options, and timing.',
#   'questions': ['By what date must a divisional be filed if the parent is due to grant?',
#    'Can a divisional be filed in a different language than its parent?']},
#  {'topic': '3. Divisional applications',
#   'subtopic': '3.2 Subject-matter and scope',
#   'scope': 'compliance with article 76 epc, no added subject-matter, and ensuring unity.',
#   'questions': ['How is added subject-matter assessed in a divisional relative to the parent’s original disclosure?',
#    'Can a divisional cover an invention that was excluded from the parent’s search due to lack of unity?']},
#  {'topic': '3. Divisional applications',
#   'subtopic': '3.3 Fees for divisionals',
#   'scope': 'payment of filing fees, renewal fees, examination fees, and other relevant costs.',
#   'questions': ['When are renewal fees due for a divisional application compared to its parent?',
#    'Is any reduction possible for the filing or examination fee of a divisional?']},
#  {'topic': '4. Fees, payment methods, and time limits',
#   'subtopic': '4.1 Types and calculation of fees',
#   'scope': 'understanding different fee types (filing, search, examination, renewal, claims).',
#   'questions': ['How are excess claims fees calculated if claims are amended during examination?',
#    'When must the search fee be paid if the epo acts as isa under the pct?']},
#  {'topic': '4. Fees, payment methods, and time limits',
#   'subtopic': '4.2 Payment mechanisms',
#   'scope': 'automatic debit orders, bank transfers, credit cards, and fee payment via third parties.',
#   'questions': ['How does an automatic debit order work and what happens if the deposit account lacks funds?',
#    'Can multiple applicants share a single deposit account for fee payment?']},
#  {'topic': '4. Fees, payment methods, and time limits',
#   'subtopic': '4.3 Fee deadlines and late payment consequences',
#   'scope': 'additional fees, surcharges, and further processing if deadlines are missed.',
#   'questions': ['What surcharge applies if renewal fees are not paid by the due date?',
#    'How can an applicant avoid loss of rights if a fee payment is overlooked?']},
#  {'topic': '5. Languages and translations',
#   'subtopic': '5.1 Language of filing and procedural language',
#   'scope': 'filing in non-epo official languages, subsequent translation deadlines, language-based fee reductions.',
#   'questions': ['How long after filing must a translation be submitted if the application was filed in italian?',
#    'Which official language of the epo becomes the language of proceedings if multiple languages are used?']},
#  {'topic': '5. Languages and translations',
#   'subtopic': '5.2 Translation requirements on grant or other stages',
#   'scope': 'claim translations under rule 71(3) epc, translation for validation in national phases.',
#   'questions': ['What is required if the text intended for grant is not in the applicant’s preferred official language?',
#    'Does the applicant need to file translations in all contracting states after grant?']},
#  {'topic': '5. Languages and translations',
#   'subtopic': '5.3 Effects of language on costs and procedural rights',
#   'scope': 'fee reductions for certain languages, language-based rights of small entities or universities.',
#   'questions': ['What reduction in examination fees applies for a university filing in an official language of an epc contracting state?',
#    'Can an applicant who filed in spanish benefit from a fee reduction?']},
#  {'topic': '6. Procedural remedies and legal effect',
#   'subtopic': '6.1 Further processing (rule 135 epc)',
#   'scope': 'available for missed deadlines in examination or other proceedings, scope of remedy, exceptions.',
#   'questions': ['For which official time limits is further processing not available?',
#    'How must an applicant request further processing after failing to respond to an examination report?']},
#  {'topic': '6. Procedural remedies and legal effect',
#   'subtopic': '6.2 Re-establishment of rights (article 122 epc)',
#   'scope': 'conditions (all due care), time limit for requesting, and required evidence.',
#   'questions': ['What steps demonstrate “all due care” to justify re-establishment?',
#    'When does the two-month time limit for re-establishment start running if an applicant misses a final deadline?']},
#  {'topic': '6. Procedural remedies and legal effect',
#   'subtopic': '6.3 Loss of rights and remedies',
#   'scope': 'notices of loss of rights, deemed withdrawals, subsequent procedural options.',
#   'questions': ['When is a communication under rule 112(1) epc issued, and how to react?',
#    'Is an appeal possible against a deemed withdrawal?']},
#  {'topic': '7. Pct procedure and entry into the european phase',
#   'subtopic': '7.1 International filing and search',
#   'scope': 'filing at receiving offices, international search by epo or other isas, invited corrections.',
#   'questions': ['Which receiving office can a us applicant choose when filing a pct application?',
#    'What happens if the applicant fails to pay the international filing fee within the deadline?']},
#  {'topic': '7. Pct procedure and entry into the european phase',
#   'subtopic': '7.2 Preliminary examination and amendments',
#   'scope': 'filing a demand, timing for article 34 amendments, unity objections at iper stage.',
#   'questions': ['When must the demand for international preliminary examination be filed at the epo as ipea?',
#    'How are amendments under article 34 pct handled differently from article 19 pct amendments?']},
#  {'topic': '7. Pct procedure and entry into the european phase',
#   'subtopic': '7.3 European phase entry and requirements',
#   'scope': 'minimum actions to enter ep phase (translations, fees, etc.), optional actions (requesting examination).',
#   'questions': ['What are the minimum requirements to validly enter the european phase under articles 22/39 pct?',
#    'Is an additional search fee always required in the ep phase if the epo was the isa?']},
#  {'topic': '8. Examination, amendments, and grant',
#   'subtopic': '8.1 Examination procedure and communications',
#   'scope': 'responding to article 94(3) communications, telephone consultations with examiners, time limit extensions.',
#   'questions': ['What are the applicant’s options upon receiving an objection regarding lack of clarity under article 84?',
#    'Is an in-person hearing possible before the examining division issues a final decision?']},
#  {'topic': '8. Examination, amendments, and grant',
#   'subtopic': '8.2 Claim amendments and article 123 epc',
#   'scope': 'no added subject-matter, no broadening after grant, clarity considerations.',
#   'questions': ['How is an amendment evaluated for compliance with article 123(2)?',
#    'When is it permissible to delete features from the original independent claim?']},
#  {'topic': '8. Examination, amendments, and grant',
#   'subtopic': '8.3 Grant stage (rule 71(3) epc) and post-grant publication',
#   'scope': 'paying the fee for grant and publishing, submitting claim translations, final text for publication.',
#   'questions': ['What steps must be completed before the decision to grant is issued?',
#    'What happens if errors are found in the druckexemplar after paying the grant fee?']},
#  {'topic': '9. Opposition and appeals',
#   'subtopic': '9.1 Grounds for opposition (article 100 epc)',
#   'scope': 'novelty, inventive step, subject-matter not patentable, insufficiency of disclosure, extension beyond original filing.',
#   'questions': ['Can an opponent rely on lack of clarity under article 84 epc as a ground for opposition?',
#    'Is lack of unity a valid ground for opposition?']},
#  {'topic': '9. Opposition and appeals',
#   'subtopic': '9.2 Opposition procedure and admissibility',
#   'scope': 'formal requirements (time limits, opponent identity), partial opposition, withdrawal of opposition.',
#   'questions': ['Is it possible to oppose only one independent claim of a granted patent?',
#    'How does the epo handle late-filed documents in opposition?']},
#  {'topic': '9. Opposition and appeals',
#   'subtopic': '9.3 Appeal proceedings',
#   'scope': 'grounds of appeal, fresh evidence, remittal, boards’ powers, and procedures.',
#   'questions': ['Can a new ground for opposition be introduced during appeal without the patentee’s consent?',
#    'What is the composition of a board of appeal deciding a patent case?']},
#  {'topic': '10. Substantive patent law: novelty and inventive step',
#   'subtopic': '10.1 Novelty analysis',
#   'scope': 'defining prior art, comparing features, selection inventions, disclaimers.',
#   'questions': ['How is novelty assessed against a document that discloses a range overlapping the claimed range?',
#    'Does prior use by the applicant themselves destroy novelty?']},
#  {'topic': '10. Substantive patent law: novelty and inventive step',
#   'subtopic': '10.2 Inventive step analysis',
#   'scope': 'closest prior art selection, objective technical problem, and problem-solution approach.',
#   'questions': ['Can a known alternative material render the claim obvious if it provides no improved result?',
#    'How does the examiner establish a lack of inventive step if the solution is an obvious combination of known teachings?']},
#  {'topic': '10. Substantive patent law: novelty and inventive step',
#   'subtopic': '10.3 Special forms of claims (e.g., medical use)',
#   'scope': 'swiss-type, article 54(5) epc second medical use claims, allowable claim wording.',
#   'questions': ['What is the difference between swiss-type claims and epc 2000 medical use claims?',
#    'How is novelty established for a second or further medical use?']},
#  {'topic': '11. Entitlement and transfers',
#   'subtopic': '11.1 Entitlement disputes (article 61 EPC)',
#   'scope': 'disputes over who owns the right to a european patent application or patent.',
#   'questions': ['How can proceedings be stayed if entitlement proceedings are initiated before a national court?',
#    'What is the effect on the ongoing examination of a pending entitlement dispute?']},
#  {'topic': '11. Entitlement and transfers',
#   'subtopic': '11.2 Transfers and assignments',
#   'scope': 'formalities for registering changes in ownership, partial transfers, and licensing.',
#   'questions': ['Which documents are needed to record a transfer of rights in the european patent register?',
#    'Does a partial assignment allow different co-owners in different designated states?']},
#  {'topic': '11. Entitlement and transfers',
#   'subtopic': '11.3 Procedural consequences',
#   'scope': 'impact on deadlines, actions that can/cannot be taken by a transferee before registration.',
#   'questions': ['At what point can the transferee begin prosecuting the application in their own name?',
#    'Is there a fee for recording a transfer at the epo?']},
#  {'topic': '12. Biotech and sequence listings',
#   'subtopic': '12.1 Sequence listing filing and format',
#   'scope': 'mandatory wipo standard, electronic submission, late furnishing fees.',
#   'questions': ['What are the consequences if a sequence listing is not filed upon request?',
#    'In what format must the sequence listing be provided under wipo standard st.25 or st.26?']},
#  {'topic': '12. Biotech and sequence listings',
#   'subtopic': '12.2 Added subject-matter in biotech claims',
#   'scope': 'ensuring that no new sequences or mutations are introduced beyond the original disclosure.',
#   'questions': ['How is compliance with article 123(2) epc checked for nucleotide and amino acid sequences?']},
#  {'topic': '12. Biotech and sequence listings',
#   'subtopic': '12.3 Specific patentability exceptions in biotech',
#   'scope': 'exclusions (plant/animal varieties, essentially biological processes), rule 28 epc.',
#   'questions': ['What biotech inventions are explicitly excluded from patentability under the epc?',
#    'Does the epc allow gene editing claims for plants?']},
#  {'topic': '13. Unity of invention',
#   'subtopic': '13.1 Unity in european applications',
#   'scope': 'criteria for single general inventive concept, partial search where unity is lacking.',
#   'questions': ['How does the epo handle multiple independent claims that appear unrelated?',
#    'Can the epo invite payment of additional search fees for non-unified claims during ep examination?']},
#  {'topic': '13. Unity of invention',
#   'subtopic': '13.2 Unity in pct applications',
#   'scope': 'international phase unity criteria, additional fees for multiple inventions, protest procedure.',
#   'questions': ['What steps can an applicant take if the isa invites payment of additional search fees?',
#    'Is it possible to pursue unsearched inventions in a later european divisional?']},
#  {'topic': '13. Unity of invention',
#   'subtopic': '13.3 Strategies for overcoming lack of unity',
#   'scope': 'amendments, selecting one invention to proceed with, potential divisional filings.',
#   'questions': ['Which claims should be retained if the applicant pays no additional search fees?',
#    'How does an applicant choose the invention providing the strongest prospect of allowance?']}]

# %%
mappings = []
mappings.append(pd.read_json("../../resources/questions/table0.json"))
mappings.append(pd.read_json("../../resources/questions/table1.json"))
mappings.append(pd.read_json("../../resources/questions/table2.json"))

# %%
import re

def extract_num(text):
    match = re.match(r"^\d+(?:\.\d+)*", text)
    if match:
        return match.group()

categories = {}
for _, row in mappings[0].iloc[0:10].iterrows():
    category = str(extract_num(row["Category"]))
    subcategory = str(extract_num(row["Subcategory"]))
    qnum = row["Question"]
    exam = "EQE_2022_PreEx_final_documentLess.json"
    if category not in categories:
        categories[category] = {}
    if subcategory not in categories[category]:
        categories[category][subcategory] = []
    categories[category][subcategory].append((exam, int(qnum[1:])))

for _, row in mappings[1].iloc[0:10].iterrows():
    category = str(extract_num(row["Category"]))
    subcategory = str(extract_num(row["Subcategory"]))
    qnum = row["Question"]
    exam = "EQE_2021_PreEx_final_documentLess.json"
    if category not in categories:
        categories[category] = {}
    if subcategory not in categories[category]:
        categories[category][subcategory] = []
    categories[category][subcategory].append((exam, int(qnum[1:])))

for _, row in mappings[2].iterrows():
    category = str(extract_num(row["Category"]))
    subcategory = str(extract_num(row["Subcategory"]))
    qnum = row["Q"]
    exam = "EOB.json"
    if category not in categories:
        categories[category] = {}
    if subcategory not in categories[category]:
        categories[category][subcategory] = []
    categories[category][subcategory].append((exam, int(qnum)))

# %%
import json
with open("categories2questions.json", 'w') as cs:
    json.dump(categories, cs)

# %%
count = 0
for category in categories:
    for subcategory in categories[category]:
        count += len(categories[category][subcategory])

# %%
categories
# Out:
# {'11': {'11.1': [('EQE_2022_PreEx_final_documentLess.json', 1)],
#   '11.2': [('EQE_2022_PreEx_final_documentLess.json', 4),
#    ('EOB.json', 5),
#    ('EOB.json', 20)]},
#  '9': {'9.1': [('EQE_2022_PreEx_final_documentLess.json', 2),
#    ('EQE_2021_PreEx_final_documentLess.json', 5),
#    ('EOB.json', 14)],
#   '9.3': [('EQE_2022_PreEx_final_documentLess.json', 3),
#    ('EQE_2021_PreEx_final_documentLess.json', 8),
#    ('EOB.json', 18)],
#   '9.2': [('EQE_2022_PreEx_final_documentLess.json', 10),
#    ('EOB.json', 15),
#    ('EOB.json', 16),
#    ('EOB.json', 17),
#    ('EOB.json', 30),
#    ('EOB.json', 31)],
#   'None': [('EOB.json', 19), ('EOB.json', 22)]},
#  '5': {'5.1': [('EQE_2022_PreEx_final_documentLess.json', 5),
#    ('EQE_2021_PreEx_final_documentLess.json', 9)],
#   '5.3': [('EOB.json', 1), ('EOB.json', 24)]},
#  '3': {'3.1': [('EQE_2022_PreEx_final_documentLess.json', 6),
#    ('EQE_2021_PreEx_final_documentLess.json', 3),
#    ('EOB.json', 8),
#    ('EOB.json', 23)]},
#  '10': {'10.3': [('EQE_2022_PreEx_final_documentLess.json', 7)],
#   '10.1': [('EOB.json', 42)]},
#  '7': {'7.1': [('EQE_2022_PreEx_final_documentLess.json', 8),
#    ('EQE_2021_PreEx_final_documentLess.json', 4),
#    ('EQE_2021_PreEx_final_documentLess.json', 10),
#    ('EOB.json', 4),
#    ('EOB.json', 33),
#    ('EOB.json', 34),
#    ('EOB.json', 35),
#    ('EOB.json', 36),
#    ('EOB.json', 37),
#    ('EOB.json', 38)],
#   '7.3': [('EOB.json', 40),
#    ('EOB.json', 43),
#    ('EOB.json', 45),
#    ('EOB.json', 48)]},
#  '1': {'1.1': [('EQE_2022_PreEx_final_documentLess.json', 9)],
#   '1.3': [('EOB.json', 6),
#    ('EOB.json', 13),
#    ('EOB.json', 27),
#    ('EOB.json', 49)]},
#  '4': {'4.1': [('EQE_2021_PreEx_final_documentLess.json', 1),
#    ('EOB.json', 32)],
#   '4.2': [('EOB.json', 7)],
#   '4.3': [('EOB.json', 9), ('EOB.json', 10), ('EOB.json', 41)]},
#  '2': {'2.1': [('EQE_2021_PreEx_final_documentLess.json', 2),
#    ('EOB.json', 50)],
#   '2.2': [('EOB.json', 11),
#    ('EOB.json', 12),
#    ('EOB.json', 39),
#    ('EOB.json', 46),
#    ('EOB.json', 47)]},
#  '8': {'8.1': [('EQE_2021_PreEx_final_documentLess.json', 6),
#    ('EQE_2021_PreEx_final_documentLess.json', 7),
#    ('EOB.json', 21)],
#   '8.2': [('EOB.json', 25),
#    ('EOB.json', 26),
#    ('EOB.json', 28),
#    ('EOB.json', 29)]},
#  '6': {'None': [('EOB.json', 2), ('EOB.json', 3), ('EOB.json', 44)]}}

# %%
txt = "Where evidence is provided that a final decision within the meaning of Article 61, paragraph 1, has been taken, the European Patent Office shall inform the applicant and any other party that the proceedings for grant shall be resumed as from the date stated in the communication, unless a new European patent application under Article 61, paragraph 1(b), has been filed for all the designated Contracting States. If the decision is in favour of the third party, the proceedings may not be resumed earlier than three months after the decision has become final, unless the third party requests the resumption."

len(txt.split(' '))
# Out:
# 100

# %%
import pandas as pd
from docx.api import Document

document = Document("../../resources/Categories.docx")
tables = document.tables
for k, table in enumerate(tables):
    data = []

    keys = None
    for i, row in enumerate(table.rows):
        text = (cell.text for cell in row.cells)

        if i == 0:
            keys = tuple(text)
            continue
        row_data = dict(zip(keys, text))
        data.append(row_data)
    print (data)

    df = pd.DataFrame(data)
    df.to_json(f"../../resources/questions/table{k}.json")
# Out:
# [{'Question': 'Q1', 'Category': '11. Entitlement and Transfers', 'Subcategory': '11.1 Entitlement Disputes'}, {'Question': 'Q2', 'Category': '9. Opposition and Appeals', 'Subcategory': '9.1/9.2 (Grounds/Procedure)'}, {'Question': 'Q3', 'Category': '9. Opposition and Appeals', 'Subcategory': '9.3 Appeal Proceedings'}, {'Question': 'Q4', 'Category': '11. Entitlement and Transfers', 'Subcategory': '11.2 Transfers and Assignments'}, {'Question': 'Q5', 'Category': '5. Languages and Translations', 'Subcategory': '5.1 Language of Filing / Procedural Language'}, {'Question': 'Q6', 'Category': '3. Divisional Applications', 'Subcategory': '3.1 Filing Requirements'}, {'Question': 'Q7', 'Category': '10. Substantive Patent Law', 'Subcategory': '10.3 Special Forms (Medical Use)'}, {'Question': 'Q8', 'Category': '7. PCT Procedure and Entry into EP Phase', 'Subcategory': '7.1 International Filing and Search'}, {'Question': 'Q9', 'Category': '1. Filing Requirements and Formalities', 'Subcategory': '1.1 (Filing Date) / 1.3 (Representation as part of formality check)'}, {'Question': 'Q10', 'Category': '9. Opposition and Appeals', 'Subcategory': '9.2 Opposition Procedure / Admissibility'}, {'Question': 'Q11', 'Category': '8. Examination, Amendments, and Grant', 'Subcategory': '8.1 Examination Procedure (Clarity & Claim Construction)'}, {'Question': 'Q12', 'Category': '10. Substantive Patent Law', 'Subcategory': '10.1 Novelty Analysis'}, {'Question': 'Q13', 'Category': '10. Substantive Patent Law', 'Subcategory': '10.1 Novelty Analysis'}, {'Question': 'Q14', 'Category': '8. Examination, Amendments, and Grant', 'Subcategory': '8.2 Claim Amendments and Article 123(2)/84'}, {'Question': 'Q15', 'Category': '10. Substantive Patent Law', 'Subcategory': '10.1 (Novelty) & 10.2 (Inventive Step)'}, {'Question': 'Q16', 'Category': '10. Substantive Patent Law', 'Subcategory': '10.1 Novelty Analysis'}, {'Question': 'Q17', 'Category': '10. Substantive Patent Law', 'Subcategory': '10.1 Novelty Analysis'}, {'Question': 'Q18', 'Category': '8. Examination, Amendments, and Grant', 'Subcategory': '8.1 Examination Procedure & possibly 8.2 (Article 123(2))'}, {'Question': 'Q19', 'Category': '8. Examination, Amendments, and Grant', 'Subcategory': '8.2 Claim Amendments and Article 123(2)'}, {'Question': 'Q20', 'Category': '10. Substantive Patent Law', 'Subcategory': '10.2 Inventive Step Analysis'}]
# [{'Question': 'Q1', 'Category': '4. Fees, Payment Methods, and Time Limits', 'Subcategory': '4.1 Types & Calculation of Fees / 4.3 Deadlines'}, {'Question': 'Q2', 'Category': '2. Priority Claims and Right of Priority', 'Subcategory': '2.1 Substantive Requirements, 2.2 Time Limits'}, {'Question': 'Q3', 'Category': '3. Divisional Applications', 'Subcategory': '3.1 Filing Requirements / 3.2 Subject-Matter and Scope'}, {'Question': 'Q4', 'Category': '7. PCT Procedure and Entry into the European Phase', 'Subcategory': '7.1 International Filing and Search (plus minor Article 54(3) aspects)'}, {'Question': 'Q5', 'Category': '9. Opposition and Appeals', 'Subcategory': '9.1 Grounds for Opposition & Admissibility / 9.2 Opposition Procedure'}, {'Question': 'Q6', 'Category': '8. Examination, Amendments, and Grant', 'Subcategory': '8.1 Examination Procedure (focus on sufficiency, Art. 83)'}, {'Question': 'Q7', 'Category': '8. Examination, Amendments, and Grant', 'Subcategory': '8.1 Examination Procedure (oral proceedings, who may speak)'}, {'Question': 'Q8', 'Category': '9. Opposition and Appeals', 'Subcategory': '9.3 Appeal Proceedings (fresh grounds)'}, {'Question': 'Q9', 'Category': '5. Languages and Translations', 'Subcategory': '5.1 Language of Filing/Procedural Language'}, {'Question': 'Q10', 'Category': '7. PCT Procedure and Entry into the European Phase', 'Subcategory': '7.1 International Filing and Search (unity, protest fees)'}, {'Question': 'Q11', 'Category': '10. Substantive Patent Law: Novelty/Inventive Step', 'Subcategory': '(Claim scope interpretation; product-by-process coverage)'}, {'Question': 'Q12', 'Category': '8. Examination, Amendments, and Grant', 'Subcategory': '8.1 Examination Procedure (Art. 84 clarity, essential features)'}, {'Question': 'Q13', 'Category': '10. Substantive Patent Law: Novelty and Inventive Step', 'Subcategory': '10.1 Novelty Analysis'}, {'Question': 'Q14', 'Category': '8. Examination, Amendments, and Grant', 'Subcategory': '8.2 Claim Amendments & Article 123(2)'}, {'Question': 'Q15', 'Category': '10. Substantive Patent Law: Novelty and Inventive Step', 'Subcategory': '10.2 Inventive Step Analysis'}, {'Question': 'Q16', 'Category': '8. Examination, Amendments, and Grant', 'Subcategory': '8.1 Examination Procedure (clarity, scope)'}, {'Question': 'Q17', 'Category': '10. Substantive Patent Law: Novelty and Inventive Step', 'Subcategory': '10.1 Novelty Analysis'}, {'Question': 'Q18', 'Category': '10. Substantive Patent Law: Novelty and Inventive Step', 'Subcategory': '10.1 Novelty Analysis'}, {'Question': 'Q19', 'Category': '8. Examination, Amendments, and Grant', 'Subcategory': '8.2 Claim Amendments & Article 123(2)'}, {'Question': 'Q20', 'Category': '10. Substantive Patent Law: Novelty and Inventive Step', 'Subcategory': '10.2 Inventive Step Analysis (including two-part form re: D2)'}]
# [{'Q': '1', 'Topic (Short)': '20% exam fee reduction (Spanish)', 'Category': '5. Languages & Translations', '': '', 'Subcategory': '5.3 Effects of Language on Costs/Rights'}, {'Q': '2', 'Topic (Short)': 'Stay of proceedings & renewal fees', 'Category': '6. Procedural Remedies & Legal Effect', '': '', 'Subcategory': '(Stay of proceedings under Rule 14(4))'}, {'Q': '3', 'Topic (Short)': 'Interruption (Rule 142) & resuming an opposition time limit', 'Category': '6. Procedural Remedies & Legal Effect', '': '', 'Subcategory': '(Interruption/resumption)'}, {'Q': '4', 'Topic (Short)': 'Correcting inventor in PCT vs. EPC (consent not required vs. required)', 'Category': '7. PCT Procedure & Entry into EP Phase', '': '', 'Subcategory': '7.1 International Filing & Search'}, {'Q': '5', 'Topic (Short)': 'Recording sub-licence in EP Register', 'Category': '11. Entitlement & Transfers', '': '', 'Subcategory': '11.2 Transfers & Assignments (Licences)'}, {'Q': '6', 'Topic (Short)': 'Exhibition priority certificate refused if not issued at exhibition', 'Category': '1. Filing Requirements & Formalities', '': '', 'Subcategory': '1.3 Formality Examination or a special Art. 55(1)(b) case'}, {'Q': '7', 'Topic (Short)': 'Payment date of exam fee via bank transfer', 'Category': '4. Fees, Payment & Time Limits', '': '', 'Subcategory': '4.2 Payment Mechanisms / 4.3 Deadlines'}, {'Q': '8', 'Topic (Short)': 'Filing a divisional after refusal, still within appeal period (G1/09)', 'Category': '3. Divisional Applications', '': '', 'Subcategory': '3.1 Filing Requirements'}, {'Q': '9', 'Topic (Short)': 'Renewal fees can be paid up to 3 months early', 'Category': '4. Fees, Payment & Time Limits', '': '', 'Subcategory': '4.3 Fee Deadlines'}, {'Q': '10', 'Topic (Short)': 'Article 61(1)(b) new application, first renewal fee date', 'Category': '4. Fees, Payment & Time Limits', '': '', 'Subcategory': '4.3 Fee Deadlines'}, {'Q': '11', 'Topic (Short)': 'Too late to add a priority claim (Rule 52(2) EPC)', 'Category': '2. Priority Claims & Right of Priority', '': '', 'Subcategory': '2.2 Time Limits & Restoration'}, {'Q': '12', 'Topic (Short)': 'Effect of not filing priority document: loss of priority right', 'Category': '2. Priority Claims & Right of Priority', '': '', 'Subcategory': '2.2 Time Limits & Restoration'}, {'Q': '13', 'Topic (Short)': 'Inventor designation due date (Rule 60(1))', 'Category': '1. Filing Requirements & Formalities', '': '', 'Subcategory': '1.3 Formality Examination'}, {'Q': '14', 'Topic (Short)': 'Amended feature was “result to be achieved,” clarity not re-opened', 'Category': '9. Opposition & Appeals', '': '', 'Subcategory': '9.1 / 9.2 (G 3/14 in opposition)'}, {'Q': '15', 'Topic (Short)': 'Oppose a lapsed/surrendered patent (ex nunc vs. ex tunc)', 'Category': '9. Opposition & Appeals', '': '', 'Subcategory': '9.2 Opposition Procedure'}, {'Q': '16', 'Topic (Short)': 'Amendment in opposition not occasioned by ground (Rule 80, clarity only)', 'Category': '9. Opposition & Appeals', '': '', 'Subcategory': '9.2 Opposition Procedure'}, {'Q': '17', 'Topic (Short)': 'Intervention in appeal, only pay opposition fee', 'Category': '9. Opposition & Appeals', '': '', 'Subcategory': '9.2 or 9.3 (Intervention at appeal stage)'}, {'Q': '18', 'Topic (Short)': 'Intervener is entitled to appeal', 'Category': '9. Opposition & Appeals', '': '', 'Subcategory': '9.3 Appeal Proceedings'}, {'Q': '19', 'Topic (Short)': 'Request for revocation by proprietor, existence of exclusive licensee', 'Category': '9. Opposition & Appeals', '': '', 'Subcategory': '(Central revocation procedure)'}, {'Q': '20', 'Topic (Short)': 'Recording exclusive licence in EP Register', 'Category': '11. Entitlement & Transfers', '': '', 'Subcategory': '11.2 Transfers & Assignments (Licences)'}, {'Q': '21', 'Topic (Short)': 'PACE request by fax not valid, examination can start but not accelerated', 'Category': '8. Examination, Amendments & Grant', '': '', 'Subcategory': '8.1 Examination Procedure' ...

# %%
mappings[2]
# Out:
#      Q                                      Topic (Short)  \
# 0    1                   20% exam fee reduction (Spanish)
# 1    2                 Stay of proceedings & renewal fees
# 2    3  Interruption (Rule 142) & resuming an oppositi...
# 3    4  Correcting inventor in PCT vs. EPC (consent no...
# 4    5               Recording sub-licence in EP Register
# 5    6  Exhibition priority certificate refused if not...
# 6    7         Payment date of exam fee via bank transfer
# 7    8  Filing a divisional after refusal, still withi...
# 8    9      Renewal fees can be paid up to 3 months early
# 9   10  Article 61(1)(b) new application, first renewa...
# 10  11  Too late to add a priority claim (Rule 52(2) EPC)
# 11  12  Effect of not filing priority document: loss o...
# 12  13         Inventor designation due date (Rule 60(1))
# 13  14  Amended feature was “result to be achieved,” c...
# 14  15  Oppose a lapsed/surrendered patent (ex nunc vs...
# 15  16  Amendment in opposition not occasioned by grou...
# 16  17    Intervention in appeal, only pay opposition fee
# 17  18                   Intervener is entitled to appeal
# 18  19  Request for revocation by proprietor, existenc...
# 19  20         Recording exclusive licence in EP Register
# 20  21  PACE request by fax not valid, examination can...
# 21  22  Art. 115 obs. in limitation proceedings re: pa...
# 22  23  Last day to file divisional (day before public...
# 23  24  Fee reduction for additional pages (part of fi...
# 24  25  Amendment is an intermediate generalization (A...
# 25  26  Omitting “asbestos” from a 4-element list is p...
# 26  27  When an authorization is required & consequenc...
# 27  28  Last date for Rule 139 correction before grant...
# 28  29  No correction after grant decision is dispatch...
# 29  30  Filing an opposition as a “straw man” (G 3/97,...
# 30  31  Changing method claim to device claim in oppos...
# 31  32  Withdrawing application after first exam comm....
# 32  33  Late payment of PCT filing fees but before inv...
# 33  34  Multiple PCT applicants, withdrawal needs all ...
# 34  35  Withdrawing a PCT app. to prevent publication ...
# 35  36  Correct inventor in int. phase better (no need...
# 36  37                          Third-party obs. via ePCT
# 37  38  EPO as RO sets 2-month time; date of mailing, ...
# 38  39   EPO uses “all due care” for priority restoration
# 39  40  Missed 31-month deadline, further processing f...
# 40  41  Renewal fee 3rd year for Euro-PCT app. date of...
# 41  42                 PCT-1 is A54(3) prior art for EP-1
# 42  43  No unity in PCT, pay addl. fee after EPO invit...
# 43  44  Receiving section can refuse OP request (Art. ...
# 44  45              Early entry & which fees must be paid
# 45  46  Priority restored under “unintentional,” EPO d...
# 46  47  Priority from KR utility model; translation on...
# 47  48   No translation on EP entry => further processing
# 48  49  Japanese applicant can do R.159(1) acts themse...
# 49  50  Two French priorities: first for A, second for...
#
#                                              Category    \
# 0                         5. Languages & Translations
# 1               6. Procedural Remedies & Legal Effect
# 2               6. Procedural Remedies & Legal Effect
# 3              7. PCT Procedure & Entry into EP Phase
# 4                         11. Entitlement & Transfers
# 5                1. Filing Requirements & Formalities
# 6                      4. Fees, Payment & Time Limits
# 7                          3. Divisional Applications
# 8                      4. Fees, Payment & Time Limits
# 9                      4. Fees, Payment & Time Limits
# 10             2. Priority Claims & Right of Priority
# 11             2. Priority Claims & Right of Priority
# 12               1. Filing Requirements & Formalities
# 13                            9. Opposition & Appeals
# 14                            9. Opposition & Appeals
# 15                            9. Opposition & Appeals
# 16                            9. Opposition & Appeals
# 17                            9. Opposition & Appeals
# 18                            9. Opposition & Appeals
# 19                        11. Entitlement & Transfers
# 20                 8. Examination, Amendments & Grant
# 21            9. Opposition & Appeals (or post-grant)
# 22                         3. Divisional Applications
# 23                        5. Languages & Translations
# 24                 8. Examination, Amendments & Grant
# 25                 8. Examination, Amendments & Grant
# 26               1. Filing Requirements & Formalities
# 27                 8. Examination, Amendments & Grant
# 28                 8. Examination, Amendments & Grant
# 29                            9. Opposition & Appeals
# 30                            9. Opposition & Appeals
# 31                     4. Fees, Payment & Time Limits
# 32                        7. PCT Procedure & EP Phase
# 33                        7. PCT Procedure & EP Phase
# 34                        7. PCT Procedure & EP Phase
# 35                        7. PCT Procedure & EP Phase
# 36                        7. PCT Procedure & EP Phase
# 37                        7. PCT Procedure & EP Phase
# 38             2. Priority Claims & Right of Priority
# 39                        7. PCT Procedure & EP Phase
# 40                     4. Fees, Payment & Time Limits
# 41  10. Substantive Patent Law: Novelty & Inventiv...
# 42          7. PCT Procedure & EP Phase, or 13. Unity
# 43              6. Procedural Remedies & Legal Effect
# 44                        7. PCT Procedure & EP Phase
# 45             2. Priority Claims & Right of Priority
# 46             2. Priority Claims & Right of Priority
# 47                        7. PCT Procedure & EP Phase
# 48               1. Filing Requirements & Formalities
# 49             2. Priority Claims & Right of Priority
#
#                                           Subcategory
# 0             5.3 Effects of Language on Costs/Rights
# 1              (Stay of proceedings under Rule 14(4))
# 2                           (Interruption/resumption)
# 3                   7.1 International Filing & Search
# 4             11.2 Transfers & Assignments (Licences)
# 5   1.3 Formality Examination or a special Art. 55...
# 6              4.2 Payment Mechanisms / 4.3 Deadlines
# 7                             3.1 Filing Requirements
# 8                                   4.3 Fee Deadlines
# 9                                   4.3 Fee Deadlines
# 10                      2.2 Time Limits & Restoration
# 11                      2.2 Time Limits & Restoration
# 12                          1.3 Formality Examination
# 13                   9.1 / 9.2 (G 3/14 in opposition)
# 14                           9.2 Opposition Procedure
# 15                           9.2 Opposition Procedure
# 16          9.2 or 9.3 (Intervention at appeal stage)
# 17                             9.3 Appeal Proceedings
# 18                     (Central revocation procedure)
# 19            11.2 Transfers & Assignments (Licences)
# 20                          8.1 Examination Procedure
# 21  (Limitation is not strictly opposition, but cl...
# 22                            3.1 Filing Requirements
# 23            5.3 Effects of Language on Costs/Rights
# 24              8.2 Claim Amendments & Article 123(2)
# 25              8.2 Claim Amendments & Article 123(2)
# 26                          1.3 Formality Examination
# 27         8.2 (Corrections under 139 up to decision)
# 28                       8.2 (No correction possible)
# 29                           9.2 Opposition Procedure
# 30                           9.2 Opposition Procedure
# 31                      4.1 or 4.3 (Refund specifics)
# 32          7.1 Int. Filing & Search (Rule 16bis PCT)
# 33                  7.1 International Filing & Search
# 34                  7.1 International Filing & Search
# 35                  7.1 International Filing & Search
# 36                  7.1 International Filing & Search
# 37                  7.1 International Filing & Search
# 38                      2.2 Time Limits & Restoration
# 39                  7.3 EP Phase Entry & Requirements
# 40                                      4.3 Deadlines
# 41                              10.1 Novelty Analysis
# 42                 7.3 EP Phase & 13 Unity (Rule 164)
# 43              (General OP rules, receiving section)
# 44                  7.3 EP Phase Entry & Requirements
# 45                      2.2 Time Limits & Restoration
# 46    2.2 or 2.3 (Focus: translation of priority doc)
# 47                  7.3 EP Phase Entry & Requirements
# 48         1.3 Formality Examination (Representation)
# 49        2.1 Substantive Requirements (first filing)
